# %%
import pandas as pd
import geopandas as gpd

# %%
data_gdb = gpd.read_file('QFaults_2018.gdb')
data_shp = gpd.read_file('Qfaults_2018_shapefile/Qfaults_2018_shapefile.shp')
data_fauls_shp = gdp.read_file('Qfaults_2018_shapefile/qfault_areas.shp')
data_fauls_sbn = gdp.read_file('Qfaults_2018_shapefile/qfault_areas.sbn')

# %%
data_fauls_shp = gpd.read_file('Qfaults_2018_shapefile/qfault_areas.shp')
data_fauls_sbn = gpd.read_file('Qfaults_2018_shapefile/qfault_areas.sbn')
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# fiona/_shim.pyx in fiona._shim.gdal_open_vector()
#
# fiona/_err.pyx in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: 'Qfaults_2018_shapefile/qfault_areas.sbn' not recognized as a supported file format.
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# <ipython-input-3-e87d36aff27a> in <module>
#       1 data_fauls_shp = gpd.read_file('Qfaults_2018_shapefile/qfault_areas.shp')
# ----> 2 data_fauls_sbn = gpd.read_file('Qfaults_2018_shapefile/qfault_areas.sbn')
#
# ~\.conda\envs\quakes\lib\site-packages\geopandas\io\file.py in read_file(filename, bbox, **kwargs)
#      69
#      70     with fiona_env():
# ---> 71         with reader(path_or_bytes, **kwargs) as features:
#      72             crs = features.crs
#      73             if bbox is not None:
#
# ~\.conda\envs\quakes\lib\site-packages\fiona\env.py in wrapper(*args, **kwargs)
#     394     def wrapper(*args, **kwargs):
#     395         if local._env:
# --> 396             return f(*args, **kwargs)
#     397         else:
#     398             if isinstance(args[0], str):
#
# ~\.conda\envs\quakes\lib\site-packages\fiona\__init__.py in open(fp, mode, driver, schema, crs, encoding, layer, vfs, enabled_drivers, crs_wkt, **kwargs)
#     251         if mode in ('a', 'r'):
#     252             c = Collection(path, mode, driver=driver, encoding=encoding,
# --> 253                            layer=layer, enabled_drivers=enabled_drivers, **kwargs)
#     254         elif mode == 'w':
#     255             if schema:
#
# ~\.conda\envs\quakes\lib\site-packages\fiona\collection.py in __init__(self, path, mode, driver, schema, crs, encoding, layer, vsi, archive, enabled_drivers, crs_wkt, ignore_fields, ignore_geometry, **kwargs)
#     157             if self.mode == 'r':
#     158                 self.session = Session()
# --> 159                 self.session.start(self, **kwargs)
#     160             elif self.mode in ('a', 'w'):
#     161                 self.session = WritingSession()
#
# fiona/ogrext.pyx in fiona.ogrext.Session.start()
#
# fiona/_shim.pyx in fiona._shim.gdal_open_vector()
#
# DriverError: 'Qfaults_2018_shapefile/qfault_areas.sbn' not recognized as a supported file format.

# %%
data_fauls_shp
# Out:
#     fault_id section_id                                         fault_area  \
# 0        924       None                   Gulf-margin normal faults, Texas
# 1       1022       None  Gulf-margin normal faults, Louisiana and Arkansas
# 2       1023       None         Reelfoot scarp and New Madrid seismic zone
# 3       1023       None         Reelfoot scarp and New Madrid seismic zone
# 4       1023       None         Reelfoot scarp and New Madrid seismic zone
# 5       1023       None         Reelfoot scarp and New Madrid seismic zone
# 6       1024       None                Wabash Valley liquefaction features
# 7       1025       None                                      Monroe uplift
# 8       1026       None                            Saline River fault zone
# 9       1027          a                          Faults of Thebes Gap area
# 10      1028          a                       Fluorspar Area fault complex
# 11      1029       None             Western Lowlands liquefaction features
# 12      1030       None     St. Louis-Cape Girardeau liquefaction features
# 13      2600          a                                     Kohala Volcano
# 14      2600          b                                     Kohala Volcano
# 15      2602          a                                   Hualalai Volcano
# 16      2602          b                                   Hualalai Volcano
# 17      2602          c                                   Hualalai Volcano
# 18      2604          b                                Kahuku fault system
# 19      2604          c                                Kahuku fault system
# 20      2606       None                               Ka'oiki seismic zone
# 21      2608          b                                    Kilauea Volcano
# 22      2608          c                                    Kilauea Volcano
# 23      2650       None                        Kentucky River fault system
# 24      2650       None                        Kentucky River fault system
# 25      2651       None                      Newbury liquefaction features
# 26      2652       None                                    Pembroke faults
# 27      2652       None                                    Pembroke faults
# 28      2653       None                      Central Virginia seismic zone
# 29      2654       None     Gulf-margin normal faults, Alabama and Florida
# 30      2655       None             Gulf-margin normal faults, Mississippi
# 31      2657       None                   Charleston liquefaction features
# 32      2660       None                                     Wiggins uplift
# 33      5293       None                                  Atsaksovluk fault
# 34      5294       None                                               None
# 35      5295       None                                               None
# 36      5550       None                               Rampart seismic zone
#
#                            age      slipsense  \
# 0                      Class B         Normal
# 1                      Class B         Normal
# 2                     historic  Right lateral
# 3                     historic  Right lateral
# 4                     historic  Right lateral
# 5                     historic  Right lateral
# 6            latest Quaternary        No data
# 7                      Class B        No data
# 8                      Class B        Various
# 9            latest Quaternary        Various
# 10             late Quaternary         Normal
# 11           latest Quaternary        No data
# 12           latest Quaternary        No data
# 13  middle and late Quaternary         Normal
# 14  middle and late Quaternary         Normal
# 15  middle and late Quaternary         Normal
# 16  middle and late Quaternary         Normal
# 17  middle and late Quaternary         Normal
# 18             late Quaternary           None
# 19             late Quaternary           None
# 20                    historic  Right lateral
# 21                    historic         Normal
# 22                    historic         Normal
# 23                     Class B         Normal
# 24                     Class B        Reverse
# 25           latest Quaternary        No data
# 26                     Class B         Normal
# 27                     Class B  Right lateral
# 28           latest Quaternary        No data
# 29                     Class B         Normal
# 30                     Class B         Normal
# 31                    historic        No data
# 32                     Class B        No data
# 33                    historic        Reverse
# 34                    historic           None
# 35                    historic           None
# 36                    historic    Strike slip
#
#                                 cooperator  \
# 0                   U.S. Geological Survey
# 1                   U.S. Geological Survey
# 2                   U.S. Geological Survey
# 3                   U.S. Geological Survey
# 4                   U.S. Geological Survey
# 5                   U.S. Geological Survey
# 6                   U.S. Geological Survey
# 7                   U.S. Geological Survey
# 8                   U.S. Geological Survey
# 9                   U.S. Geological Survey
# 10        Illinois State Geological Survey
# 11                  U.S. Geological Survey
# 12                  U.S. Geological Survey
# 13    University of California at Berkeley
# 14    University of California at Berkeley
# 15    University of California at Berkeley
# 16    University of California at Berkeley
# 17    University of California at Berkeley
# 18    University of California at Berkeley
# 19    University of California at Berkeley
# 20    University of California at Berkeley
# 21    University of California at Berkeley
# 22    University of California at Berkeley
# 23                  U.S. Geological Survey
# 24                  U.S. Geological Survey
# 25                  U.S. Geological Survey
# 26                  U.S. Geological Survey
# 27                  U.S. Geological Survey
# 28                  U.S. Geological Survey
# 29                  U.S. Geological Survey
# 30                  U.S. Geological Survey
# 31                  U.S. Geological Survey
# 32                  U.S. Geological Survey
# 33  Alaska Department of Natural Resources
# 34  Alaska Department of Natural Resources
# 35  Alaska Department of Natural Resources
# 36  Alaska Department of Natural Resources
#
#                                                   url ref_id    Shape_Leng  \
# 36  https://earthquake.usgs.gov/cfusion/qfault/sho...   5550  2.870794e+05
#
#       Shape_Area                                           geometry
# 0   4.008565e+11  POLYGON ((-94.07141736074814 33.43044922223294...
# 1   2.213205e+11  POLYGON ((-94.07141736074814 33.43044922223294...
# 2   1.291146e+10  POLYGON ((-89.62051671999586 36.38184695880091...
# 3   9.707625e+08  POLYGON ((-89.40953528778994 36.21071273326238...
# 4   1.006530e+09  POLYGON ((-89.38184079441747 36.72482235397989...
# 5   2.326396e+07  POLYGON ((-89.32851712793553 36.56994593705066...
# 6   1.035110e+11  POLYGON ((-88.94990345480734 37.28330131193474...
# 7   1.442280e+10  POLYGON ((-91.66188277440949 33.19991929525982...
# 8   3.305766e+09  POLYGON ((-91.61200971030873 33.41659576192432...
# 9   4.301165e+08  POLYGON ((-89.62373618315948 37.12317003606263...
# 10  9.906554e+08  POLYGON ((-88.49009448303389 37.06996872467198...
# 11  3.325543e+09  POLYGON ((-90.97767630744457 36.23534998280829...
# 12  1.856867e+10  POLYGON ((-89.61089985333244 38.55332116089436...
# 13  2.942158e+07  POLYGON ((-155.7175899797362 20.08761891713697...
# 14  1.355428e+07  POLYGON ((-155.6266827573992 20.03913780519427...
# 15  2.901491e+07  POLYGON ((-155.8174749802943 19.68415169265938...
# 16  1.261728e+07  POLYGON ((-155.8419527575512 19.77594336013318...
# 17  1.663614e+07  POLYGON ((-155.8262022022127 19.68355280621214...
# 18  2.440223e+07  POLYGON ((-155.5797310909591 19.49361447111129...
# 19  7.239505e+07  (POLYGON ((-155.7434810908028 19.1735450268383...
# 20  9.740376e+06  (POLYGON ((-155.3807116457378 19.4416778038217...
# 21  6.030454e+07  (POLYGON ((-155.0593188676623 19.4034116933342...
# 22  4.017108e+07  (POLYGON ((-155.4385488677204 19.1514605819826...
# 23  3.640236e+08  POLYGON ((-84.45271789788016 37.84683913886262...
# 24  3.640236e+08  POLYGON ((-84.45271789788016 37.84683913886262...
# 25  1.321899e+08  POLYGON ((-70.90854059742934 42.84110958328564...
# 26  3.462996e+09  POLYGON ((-80.46042214955237 37.14646010370653...
# 27  3.462996e+09  POLYGON ((-80.46042214955237 37.14646010370653...
# 28  1.345297e+09  POLYGON ((-78.32944821399487 37.94031466009519...
# 29  3.094920e+10  POLYGON ((-88.46489605569641 31.9379261738595,...
# 30  7.915594e+10  POLYGON ((-90.98002312378499 33.05499423165871...
# 31  1.744250e+10  POLYGON ((-79.48895832296311 33.34337561015762...
# 32  7.713043e+09  POLYGON ((-88.42760378306369 30.7311853157402,...
# 33  7.826670e+09  POLYGON ((-146.3871521256066 64.96094787710194...
# 34  2.599344e+10  POLYGON ((-147.3255748560339 65.15814137312695...
# 35  3.259471e+10  POLYGON ((-148.2174968733955 65.41314693196345...
# 36  4.828257e+09  POLYGON ((-149.8054753283839 65.59143980294834...

# %%
info = pd.read_csv('Qfaults_2018_shapefile/section_info.csv', encoding = "ISO-8859-1")
references = pd.read_csv('Qfaults_2018_shapefile/references.csv', encoding = "ISO-8859-1")

# %%
info

# %%
references
