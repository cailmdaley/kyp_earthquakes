# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot

# %%
data_shp = gpd.read_file('qfault_areas.shp')
data_shp

# %%
# %matplotlib inline
data_shp.plot()

# %%
data_shp_all = gpd.read_file('Qfaults_2018_shapefile/Qfaults_2018_shapefile.shp')
data_shp_all.sample(10)
# Out:
#                                          fault                     section  \
# 10050                  Sierra Madre fault zone      Sierra Madre C section
# 12699      Helendale-South Lockhart fault zone           Helendale section
# 2826                    San Andreas fault zone     Cholame-Carrizo section
# 21890                        San Jacinto fault  San Jacinto Valley section
# 68010                 Lisbon Valley fault zone                        None
# 38453                 Kumiva Valley fault zone                        None
# 41661  unnamed faults west of Cocoon Mountains                        None
# 6340                    San Andreas fault zone              Mojave section
# 38140         unnamed faults near Squaw Valley                        None
# 81768                       Hilton Creek fault                        None
#
#                                age   dip_direct                  slip_rate  \
# 10050              late Quaternary           NW  Between 1.0 and 5.0 mm/yr
# 12699            latest Quaternary     Vertical  Between 0.2 and 1.0 mm/yr
# 2826                      historic     Vertical     Greater than 5.0 mm/yr
# 21890            latest Quaternary     Vertical     Greater than 5.0 mm/yr
# 68010                      class B           NE        Less than 0.2 mm/yr
# 38453            latest Quaternary           SE        Less than 0.2 mm/yr
# 41661  undifferentiated Quaternary  Unspecified        Less than 0.2 mm/yr
# 6340                      historic     Vertical     Greater than 5.0 mm/yr
# 38140              late Quaternary            E        Less than 0.2 mm/yr
# 81768                     historic            E  Between 1.0 and 5.0 mm/yr
#
#           slip_sense        scale class certainty  strike  \
# 10050         Thrust     1:24,000     A      None  N68Â°W
# 12699  Right lateral     1:62,500     A      Good  N39Â°W
# 2826   Right lateral  unspecified     A      Good  N66Â°W
# 21890  Right lateral  unspecified     A      Good    None
# 68010         Normal    1:170,000     B      Good  N47Â°W
# 38453         Normal    1:250,000     A      Good  N36Â°E
# 41661         Normal    1:250,000     A      Good   N7Â°E
# 6340   Right lateral  unspecified     A      Good  N67Â°W
# 38140         Normal    1:250,000     A      Good   N2Â°E
# 81768         Normal  unspecified     A      Good  N12Â°W
#
#                          cooperator             earthquake ref_id  \
# 10050  California Geological Survey                   None   105d
# 12699  California Geological Survey                   None   110b
# 2826   California Geological Survey  Fort Tejon earthquake     1g
# 21890  California Geological Survey                   None   125b
# 68010        Utah Geological Survey                   None   2511
# 38453    Piedmont Geosciences, Inc.                   None   1619
# 41661    Piedmont Geosciences, Inc.                   None   1681
# 6340   California Geological Survey  Fort Tejon earthquake     1h
# 38140    Piedmont Geosciences, Inc.                   None   1609
# 81768  California Geological Survey                   None     44
#
#                                                fault_url fault_id section_id  \
# 10050  https://earthquake.usgs.gov/cfusion/qfault/sho...      105          d
# 12699  https://earthquake.usgs.gov/cfusion/qfault/sho...      110          b
# 2826   https://earthquake.usgs.gov/cfusion/qfault/sho...        1          g
# 21890  https://earthquake.usgs.gov/cfusion/qfault/sho...      125          b
# 68010  https://earthquake.usgs.gov/cfusion/qfault/sho...     2511       None
# 38453  https://earthquake.usgs.gov/cfusion/qfault/sho...     1619       None
# 41661  https://earthquake.usgs.gov/cfusion/qfault/sho...     1681       None
# 6340   https://earthquake.usgs.gov/cfusion/qfault/sho...        1          h
# 38140  https://earthquake.usgs.gov/cfusion/qfault/sho...     1609       None
# 81768  https://earthquake.usgs.gov/cfusion/qfault/sho...       44       None
#
#                                           symbology   Shape_Leng  \
# 10050        late Quaternary Moderately Constrained   375.056459
# 12699      latest Quaternary Moderately Constrained    61.305790
# 2826                      historic Well Constrained   189.013825
# 21890            latest Quaternary Well Constrained   114.478881
# 68010                      class B Well Constrained  5147.320064
# 38453            latest Quaternary Well Constrained   107.028935
# 41661  undifferentiated Quaternary Well Constrained   794.221433
# 6340                historic Moderately Constrained    61.865121
# 38140              late Quaternary Well Constrained   369.460207
# 81768                     historic Well Constrained   204.448598
#
#                                                 geometry
# 10050  LINESTRING (-118.114444 34.1955270000001, -118...
# 12699  LINESTRING (-117.004229999 34.49085699900009, ...
# 2826   LINESTRING (-119.902770001 35.34608500000005, ...
# 21890  LINESTRING (-116.968512 33.82266100000005, -11...
# 68010  LINESTRING (-109.085797449 38.09873284500003, ...
# 38453  LINESTRING (-119.0330416129999 40.452974797000...
# 41661  LINESTRING (-118.4796515149999 39.154935380000...
# 6340   LINESTRING (-117.7066979999999 34.385425000000...
# 38140  LINESTRING (-119.566807689 40.83895389600011, ...
# 81768  LINESTRING (-118.816403 37.61852800000009, -11...

# %%
data_shp_all.sample(10)

# %%
faults_w_eq = data_shp_all[data_shp_all['earthquake'].notnull()]
print(len(faults_w_eq))
san_andreas = faults_w_eq[faults_w_eq['fault'] == 'San Andreas fault zone']
print(len(san_andreas))
faults_w_eq
# Out:
# 12407
# 5868
#                          fault                       section  \
# 8       San Andreas fault zone          Shelter Cove Section
# 9       San Andreas fault zone          Shelter Cove Section
# 10      San Andreas fault zone          Shelter Cove Section
# 11      San Andreas fault zone          Shelter Cove Section
# 12      San Andreas fault zone          Shelter Cove Section
# ...                        ...                           ...
# 111306             Nunez fault                          None
# 111360  San Andreas fault zone           North Coast section
# 111361  San Andreas fault zone  Santa Cruz Mountains section
# 111362  San Andreas fault zone  Santa Cruz Mountains section
# 111385         Kilauea Volcano             Kilauea's caldera
#
#                                 age   dip_direct               slip_rate  \
# 8       undifferentiated Quaternary     Vertical  Greater than 5.0 mm/yr
# 9       undifferentiated Quaternary     Vertical  Greater than 5.0 mm/yr
# 10      undifferentiated Quaternary     Vertical  Greater than 5.0 mm/yr
# 11      undifferentiated Quaternary     Vertical  Greater than 5.0 mm/yr
# 12                         historic     Vertical  Greater than 5.0 mm/yr
# ...                             ...          ...                     ...
# 111306                     historic  Unspecified             Unspecified
# 111360                     historic     Vertical  Greater than 5.0 mm/yr
# 111361                     historic     Vertical  Greater than 5.0 mm/yr
# 111362                     historic     Vertical  Greater than 5.0 mm/yr
# 111385                      class B           SW  Greater than 5.0 mm/yr
#
#            slip_sense        scale class certainty      strike  \
# 8       Right lateral    1:100,000     A      Good      N12Â°W
# 9       Right lateral    1:250,000     A      Good      N12Â°W
# 10      Right lateral    1:250,000     A      Good      N12Â°W
# 11      Right lateral    1:250,000     A      Good      N12Â°W
# 12      Right lateral  unspecified     A      Good      N12Â°W
# ...               ...          ...   ...       ...         ...
# 111306  Right lateral  unspecified     A      None        None
# 111360  Right lateral     1:24,000     A      Poor      N36Â°W
# 111361  Right lateral     1:24,000     A      Good      N49Â°W
# 111362  Right lateral     1:24,000     A      Good      N49Â°W
# 111385         Normal     1:24,000     B      Good  N. 51Â° E.
#
#                           cooperator                earthquake ref_id  \
# 8       California Geological Survey  San Francisco earthquake     1a
# 9       California Geological Survey  San Francisco earthquake     1a
# 10      California Geological Survey  San Francisco earthquake     1a
# 11      California Geological Survey  San Francisco earthquake     1a
# 12      California Geological Survey  San Francisco earthquake     1a
# ...                              ...                       ...    ...
# 111306  California Geological Survey       Coalinga earthquake    289
# 111360  California Geological Survey  San Francisco earthquake     1b
# 111361  California Geological Survey  San Francisco earthquake     1d
# 111362  California Geological Survey  San Francisco earthquake     1d
# 111385        U.S. Geological Survey           Ka'u earthquake  2608a
#
#                                                 fault_url fault_id section_id  \
# 8       https://earthquake.usgs.gov/cfusion/qfault/sho...        1          a
# 9       https://earthquake.usgs.gov/cfusion/qfault/sho...        1          a
# 10      https://earthquake.usgs.gov/cfusion/qfault/sho...        1          a
# 11      https://earthquake.usgs.gov/cfusion/qfault/sho...        1          a
# 12      https://earthquake.usgs.gov/cfusion/qfault/sho...        1          a
# ...                                                   ...      ...        ...
# 111306  https://earthquake.usgs.gov/cfusion/qfault/sho...      289       None
# 111360  https://earthquake.usgs.gov/cfusion/qfault/sho...        1          b
# 111361  https://earthquake.usgs.gov/cfusion/qfault/sho...        1          d
# 111362  https://earthquake.usgs.gov/cfusion/qfault/sho...        1          d
# 111385  https://earthquake.usgs.gov/cfusion/qfault/sho...     2608          a
#
#                                                 symbology    Shape_Leng  \
# 8       undifferentiated Quaternary Moderately Constra...  42662.214988
# 9       undifferentiated Quaternary Moderately Constra...  59573.553090
# 10      undifferentiated Quaternary Moderately Constra...  68815.663027
# 11      undifferentiated Quaternary Moderately Constra...  73198.898459
# 12                                      historic Inferred   8505.454681
# ...                                                   ...           ...
# 111306                          historic Well Constrained    114.480473
# 111360                          historic Well Constrained   2150.626169
# 111361                          historic Well Constrained    183.406481
# 111362                          historic Well Constrained    183.281686
# 111385                                   class B Inferred    509.756616
#
#                                                  geometry
# 8       LINESTRING (-124.080434 39.99955100000004, -12...
# 9       LINESTRING (-123.946962 39.61670199900003, -12...
# 10      LINESTRING (-123.9484539999999 39.534763000000...
# 11      LINESTRING (-123.732129999 39.05440900000011, ...
# 12      LINESTRING (-124.07161 40.0614530010001, -124....
# ...                                                   ...
# 111306  LINESTRING (-120.45259 36.22519200100014, -120...
# 111360  LINESTRING (-123.317747 38.60325800100009, -12...
# 111361  LINESTRING (-121.641257 36.91775100100008, -12...
# 111362  LINESTRING (-121.6370429999999 36.916139999000...
# 111385  LINESTRING (-155.2598523169999 19.425665462000...
#
# [12407 rows x 19 columns]

# %%
# %matplotlib inline
san_andreas.plot()

# %%
data_gdb = gpd.read_file('QFaults_2018.gdb')
data_shp = gpd.read_file('Qfaults_2018_shapefile/Qfaults_2018_shapefile.shp')
data_fauls_shp = gdp.read_file('Qfaults_2018_shapefile/qfault_areas.shp')
data_fauls_sbn = gdp.read_file('Qfaults_2018_shapefile/qfault_areas.sbn')

# %%
data_fauls_shp = gpd.read_file('Qfaults_2018_shapefile/qfault_areas.shp')
data_fauls_sbn = gpd.read_file('Qfaults_2018_shapefile/qfault_areas.sbn')

# %%
data_fauls_shp

# %%
info = pd.read_csv('Qfaults_2018_shapefile/section_info.csv', encoding = "ISO-8859-1")
references = pd.read_csv('Qfaults_2018_shapefile/references.csv', encoding = "ISO-8859-1")

# %%
info

# %%
references
